# %%
import rasterio
import geopandas as gpd
import numpy as np
import pandas as pd
from pathlib import Path
from rasterstats import zonal_stats

# =========================================================
# PATHS
# =========================================================

ROOT = Path.cwd().parent

heatday_dir = ROOT / "data" / "monthly_heatday_scores"
output_dir = ROOT / "data" / "variables"

geojson_path = ROOT.parent / "Maps" / "Geojson" / "assam_rc_2024-11.geojson"

output_dir.mkdir(parents=True, exist_ok=True)

# =========================================================
# LOAD GEOJSON
# =========================================================

gdf = gpd.read_file(geojson_path)

if "object_id" not in gdf.columns:
    raise ValueError("object_id column missing")

gdf = gdf[["object_id", "geometry"]]

# =========================================================
# MASTER STORAGE
# =========================================================

all_records = []

# =========================================================
# LOOP
# =========================================================

years = [2021, 2022, 2023, 2024, 2025, 2026]

for year in years:

    print(f"\n================ YEAR {year} ================")

    for month in range(1, 13):

        timeperiod = f"{year}_{month:02d}"

        raster_path = heatday_dir / f"HEATDAY_{year}_{month:02d}.tif"

        print(f"\nProcessing {timeperiod}")

        if not raster_path.exists():
            print("SKIP missing raster")
            continue

        # =================================================
        # ZONAL STATS
        # =================================================

        zs = zonal_stats(
            vectors=gdf,
            raster=str(raster_path),
            stats=["mean"],
            geojson_out=True,
            nodata=np.nan
        )

        # =================================================
        # STORE RESULTS
        # =================================================

        for f in zs:

            record = {
                "object_id": f["properties"]["object_id"],
                "heat-days-score": f["properties"]["mean"],
                "timeperiod": timeperiod
            }

            all_records.append(record)

        # =================================================
        # ALSO WRITE MONTHLY FILE
        # =================================================

        df_month = pd.DataFrame([
            {
                "object_id": f["properties"]["object_id"],
                "heat-days-score": f["properties"]["mean"],
                "timeperiod": timeperiod
            }
            for f in zs
        ])

        out_csv = output_dir / f"HEATDAY_{year}_{month:02d}.csv"
        df_month.to_csv(out_csv, index=False)

        print("Saved:", out_csv)

# =========================================================
# FINAL MASTER CSV
# =========================================================

df_all = pd.DataFrame(all_records)

final_csv = output_dir / "heatdays.csv"
df_all.to_csv(final_csv, index=False)

print("\n================ DONE ================")
print("MASTER FILE SAVED:", final_csv)
# Out:
# ================ YEAR 2021 ================
#
# Processing 2021_01
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2021_01.csv
#
# Processing 2021_02
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2021_02.csv
#
# Processing 2021_03
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2021_03.csv
#
# Processing 2021_04
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2021_04.csv
#
# Processing 2021_05
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2021_05.csv
#
# Processing 2021_06
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2021_06.csv
#
# Processing 2021_07
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2021_07.csv
#
# Processing 2021_08
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2021_08.csv
#
# Processing 2021_09
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2021_09.csv
#
# Processing 2021_10
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2021_10.csv
#
# Processing 2021_11
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2021_11.csv
#
# Processing 2021_12
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2021_12.csv
#
# ================ YEAR 2022 ================
#
# Processing 2022_01
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2022_01.csv
#
# Processing 2022_02
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2022_02.csv
#
# Processing 2022_03
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2022_03.csv
#
# Processing 2022_04
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2022_04.csv
#
# Processing 2022_05
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2022_05.csv
#
# Processing 2022_06
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2022_06.csv
#
# Processing 2022_07
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2022_07.csv
#
# Processing 2022_08
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2022_08.csv
#
# Processing 2022_09
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2022_09.csv
#
# Processing 2022_10
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2022_10.csv
#
# Processing 2022_11
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2022_11.csv
#
# Processing 2022_12
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2022_12.csv
#
# ================ YEAR 2023 ================
#
# Processing 2023_01
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2023_01.csv
#
# Processing 2023_02
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2023_02.csv
#
# Processing 2023_03
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2023_03.csv
#
# Processing 2023_04
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2023_04.csv
#
# Processing 2023_05
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2023_05.csv
#
# Processing 2023_06
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2023_06.csv
#
# Processing 2023_07
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2023_07.csv
#
# Processing 2023_08
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2023_08.csv
#
# Processing 2023_09
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2023_09.csv
#
# Processing 2023_10
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2023_10.csv
#
# Processing 2023_11
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2023_11.csv
#
# Processing 2023_12
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2023_12.csv
#
# ================ YEAR 2024 ================
#
# Processing 2024_01
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2024_01.csv
#
# Processing 2024_02
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2024_02.csv
#
# Processing 2024_03
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2024_03.csv
#
# Processing 2024_04
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2024_04.csv
#
# Processing 2024_05
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2024_05.csv
#
# Processing 2024_06
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2024_06.csv
#
# Processing 2024_07
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2024_07.csv
#
# Processing 2024_08
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2024_08.csv
#
# Processing 2024_09
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2024_09.csv
#
# Processing 2024_10
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2024_10.csv
#
# Processing 2024_11
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2024_11.csv
#
# Processing 2024_12
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2024_12.csv
#
# ================ YEAR 2025 ================
#
# Processing 2025_01
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2025_01.csv
#
# Processing 2025_02
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2025_02.csv
#
# Processing 2025_03
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2025_03.csv
#
# Processing 2025_04
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2025_04.csv
#
# Processing 2025_05
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2025_05.csv
#
# Processing 2025_06
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2025_06.csv
#
# Processing 2025_07
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2025_07.csv
#
# Processing 2025_08
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2025_08.csv
#
# Processing 2025_09
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2025_09.csv
#
# Processing 2025_10
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2025_10.csv
#
# Processing 2025_11
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2025_11.csv
#
# Processing 2025_12
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2025_12.csv
#
# ================ YEAR 2026 ================
#
# Processing 2026_01
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2026_01.csv
#
# Processing 2026_02
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2026_02.csv
#
# Processing 2026_03
# Saved: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/HEATDAY_2026_03.csv
#
# Processing 2026_04
# SKIP missing raster
#
# Processing 2026_05
# SKIP missing raster
#
# Processing 2026_06
# SKIP missing raster
#
# Processing 2026_07
# SKIP missing raster
#
# Processing 2026_08
# SKIP missing raster
#
# Processing 2026_09
# SKIP missing raster
#
# Processing 2026_10
# SKIP missing raster
#
# Processing 2026_11
# SKIP missing raster
#
# Processing 2026_12
# SKIP missing raster
#
# ================ DONE ================
# MASTER FILE SAVED: /Users/saurabhlevin/Deployment/IDS-DRR_Heat/Heat-assam/data_extractor/era5_land/data/variables/heatdays.csv
